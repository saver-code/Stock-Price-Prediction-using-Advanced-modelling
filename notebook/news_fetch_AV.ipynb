# %%
# NEWS API
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey=demo

import requests as r
from dotenv import load_dotenv
import os
import pandas as pd

load_dotenv()
AV_KEY = os.getenv("AV_KEY")

# %%
symbol = "TSLA"
# news api
time_from = "20260101T0000"
time_to = "20260604T2359"
sort = "RELEVANCE"
url_base = "https://www.alphavantage.co/query?function=NEWS_SENTIMENT"
limit = 1000
url = f"{url_base}&tickers={symbol}&time_from={time_from}&time_to={time_to}&sort={sort}&limit={limit}&apikey={AV_KEY}"
res = r.get(url)

data = res.json()
df = pd.DataFrame.from_dict(data['feed'])

# %%
df['time_published'] = pd.to_datetime(df['time_published'])
df['time_published'].dt.date.value_counts()
# Out:
# time_published
# 2026-04-23    72
# 2026-05-13    45
# 2026-04-24    45
# 2026-05-14    35
# 2026-05-28    32
# 2026-05-07    32
# 2026-04-27    32
# 2026-04-29    31
# 2026-06-01    30
# 2026-05-18    30
# 2026-04-28    29
# 2026-05-05    28
# 2026-05-01    27
# 2026-05-27    26
# 2026-05-21    26
# 2026-05-12    26
# 2026-05-11    26
# 2026-05-06    26
# 2026-06-03    24
# 2026-05-26    24
# 2026-05-04    23
# 2026-04-25    23
# 2026-06-02    22
# 2026-05-19    22
# 2026-05-08    22
# 2026-05-20    19
# 2026-05-29    17
# 2026-05-15    17
# 2026-04-30    17
# 2026-05-22    16
# 2026-05-16    16
# 2026-06-04    15
# 2026-05-09    14
# 2026-05-31    12
# 2026-05-25    12
# 2026-05-23    12
# 2026-05-17    12
# 2026-04-26    12
# 2026-05-02    11
# 2026-05-24    10
# 2026-05-10    10
# 2026-05-30     9
# 2026-05-03     6
# 2026-04-22     5
# Name: count, dtype: int64

# %%
df
# Out:
#                                                  title  \
# 0    Bank of America Just Upgraded UnitedHealth Sto...
# 1    Exxon Mobil Corporation (XOM) Among the Best L...
# 2    Bernstein Remains a Hold on XPeng, Inc. Class ...
# 3    JPMorgan’s Jamie Dimon to pitch Elon Musk’s Sp...
# 4    Is Lemonade's AI-Driven Model Finally Deliveri...
# ..                                                 ...
# 995  Tesla increases spending plans as company repo...
# 996  Why Is Nio Stock Gaining Wednesday? - NIO (NYS...
# 997  Tesla's Musk says company plans to use Intel's...
# 998  NIO (NYSE:NIO) Trading Up 1% - Here's What Hap...
# 999  Fund 1 investments sells $7.55m of 1 800 FLOWE...
#
#                                                    url      time_published  \
# 0    https://www.barchart.com/story/news/2312824/ba... 2026-06-04 20:27:33
# 1    https://www.insidermonkey.com/blog/exxon-mobil... 2026-06-04 18:17:40
# 2    https://www.theglobeandmail.com/investing/mark... 2026-06-04 17:09:54
# 3    https://nypost.com/2026/06/04/business/jpmorga... 2026-06-04 17:07:49
# 4    https://www.kavout.com/market-lens/is-lemonade... 2026-06-04 15:40:01
# ..                                                 ...                 ...
# 995  https://www.theglobeandmail.com/business/artic... 2026-04-22 23:38:21
# 996  https://www.benzinga.com/trading-ideas/movers/... 2026-04-22 23:11:43
# 997  https://www.reuters.com/business/autos-transpo... 2026-04-22 22:33:21
# 998  https://www.marketbeat.com/instant-alerts/nio-... 2026-04-22 21:54:09
# 999  https://ca.investing.com/news/insider-trading-... 2026-04-22 21:40:10
#
#                                     authors  \
# 0                             [Wajeeh Khan]
# 1                           [Talha Qureshi]
# 2                                [Tipranks]
# 3                            [James Franey]
# 4                                    [NULL]
# ..                                      ...
# 995  [Akash Sriram and Abhirup Roy Reuters]
# 996                                      []
# 997                               [Reuters]
# 998                            [MarketBeat]
# 999                         [Investing.com]
#
#                                                summary  \
# 0    Bank of America has upgraded UnitedHealth (UNH...
# 1    Exxon Mobil Corporation (XOM) is considered on...
# 2    Bernstein analyst Neil Beveridge has maintaine...
# 3    JPMorgan Chase CEO Jamie Dimon will lead a nat...
# 4    Lemonade's AI-driven model is showing signific...
# ..                                                 ...
# 995  Tesla has significantly raised its spending fo...
# 996  Nio stock is gaining due to impressive deliver...
# 997  Tesla CEO Elon Musk announced that the company...
# 998  Shares of NIO (NYSE:NIO) increased by approxim...
# 999  Fund 1 Investments, LLC, a major owner of 1 80...
#
#                                           banner_image                source  \
# 0    https://media.barchart.com/contributors-admin/...          Barchart.com
# 1    https://d2w7kw43nye0pi.cloudfront.net/5WJoAQlO...        Insider Monkey
# 2    https://www.theglobeandmail.com/resizer/v2/2LQ...    The Globe and Mail
# 3    https://nypost.com/wp-content/uploads/sites/2/...         New York Post
# 4    https://investgpt-test.oss-us-east-1.aliyuncs....                Kavout
# ..                                                 ...                   ...
# 995  https://www.theglobeandmail.com/resizer/v2/QHJ...    The Globe and Mail
# 996  https://cdn.benzinga.com/cdn-cgi/image/width=1...              Benzinga
# 997  https://www.reuters.com/resizer/v2/NPDNEW75HZM...               Reuters
# 998  https://www.marketbeat.com/logos/nio-limited-l...            MarketBeat
# 999  https://i-invdn-com.investing.com/news/news_pi...  Investing.com Canada
#
#     category_within_source         source_domain  \
# 0                  General          Barchart.com
# 1                  General        Insider Monkey
# 2                  General    The Globe and Mail
# 3                  General         New York Post
# 4                  General                Kavout
# ..                     ...                   ...
# 995                General    The Globe and Mail
# 996                General              Benzinga
# 997                General               Reuters
# 998                General            MarketBeat
# 999                General  Investing.com Canada
#
#                                                 topics  \
# 0    [{'topic': 'earnings', 'relevance_score': '0.9...
# 1    [{'topic': 'financial_markets', 'relevance_sco...
# 2    [{'topic': 'earnings', 'relevance_score': '0.9...
# 3    [{'topic': 'ipo', 'relevance_score': '1.000000...
# 4    [{'topic': 'earnings', 'relevance_score': '0.9...
# ..                                                 ...
# 995  [{'topic': 'earnings', 'relevance_score': '0.9...
# 996  [{'topic': 'earnings', 'relevance_score': '0.9...
# 997  [{'topic': 'earnings', 'relevance_score': '0.8...
# 998  [{'topic': 'earnings', 'relevance_score': '0.9...
# 999  [{'topic': 'earnings', 'relevance_score': '0.9...
#
#      overall_sentiment_score overall_sentiment_label  \
# 0                   0.123811                 Neutral
# 1                   0.223840        Somewhat-Bullish
# 2                   0.037234                 Neutral
# 3                   0.277385        Somewhat-Bullish
# 4                   0.235677        Somewhat-Bullish
# ..                       ...                     ...
# 995                -0.056451                 Neutral
# 996                 0.290492        Somewhat-Bullish
# 997                 0.302500        Somewhat-Bullish
# 998                 0.127436                 Neutral
# 999                 0.204049        Somewhat-Bullish
#
#                                       ticker_sentiment
# 0    [{'ticker': 'UNH', 'relevance_score': '1.00000...
# 1    [{'ticker': 'XOM', 'relevance_score': '1.00000...
# 2    [{'ticker': 'XPEV', 'relevance_score': '1.0000...
# 3    [{'ticker': 'JPM', 'relevance_score': '1.00000...
# 4    [{'ticker': 'LMND', 'relevance_score': '1.0000...
# ..                                                 ...
# 995  [{'ticker': 'TSLA', 'relevance_score': '1.0000...
# 996  [{'ticker': 'PGJ', 'relevance_score': '0.70516...
# 997  [{'ticker': 'TSLA', 'relevance_score': '1.0000...
# 998  [{'ticker': 'NIO', 'relevance_score': '1.00000...
# 999  [{'ticker': 'FLWS', 'relevance_score': '1.0000...
#
# [1000 rows x 13 columns]

# %%
from pathlib import Path

ticker = symbol
output_dir = Path("data")
output_dir.mkdir(parents=True, exist_ok=True)
output_path = output_dir / f"{ticker}.parquet"
df_all_news.to_parquet(output_path, index=False)
print(f"Saved {len(df_all_news)} rows to {output_path}")
# Out:
# Saved 15082 rows to data\MSFT.parquet

# %%
from datetime import datetime
from pathlib import Path
import time
import pandas as pd
import requests as r

def _format_av_time(dt: datetime) -> str:
    return dt.strftime("%Y%m%dT%H%M")


def _request_news_window(symbol: str, start_dt: datetime, end_dt: datetime, api_key: str, limit: int = 1000, sort: str = "LATEST"):
    url = (
        "https://www.alphavantage.co/query"
        "?function=NEWS_SENTIMENT"
        f"&tickers={symbol}"
        f"&time_from={_format_av_time(start_dt)}"
        f"&time_to={_format_av_time(end_dt)}"
        f"&sort={sort}"
        f"&limit={limit}"
        f"&apikey={api_key}"
    )
    response = r.get(url, timeout=60)
    response.raise_for_status()
    payload = response.json()
    if "Information" in payload or "Note" in payload or "Error Message" in payload:
        raise RuntimeError(payload.get("Information") or payload.get("Note") or payload.get("Error Message"))
    return payload.get("feed", [])


def fetch_all_news_for_ticker(
    symbol: str,
    start: str = "2016-01-01T00:00",
    end: str = "2025-12-31T23:59",
    api_key: str | None = AV_KEY,
    limit: int = 1000,
    sort: str = "RELEVANCE",
    min_window_minutes: int = 60,
    pause_seconds: float = 12.5,
):
    if not api_key:
        raise ValueError("AV_KEY is missing. Set it in your environment before running this cell.")

    start_dt = datetime.fromisoformat(start)
    end_dt = datetime.fromisoformat(end)
    if start_dt >= end_dt:
        raise ValueError("start must be earlier than end")

    stack = [(start_dt, end_dt)]
    items = []

    while stack:
        window_start, window_end = stack.pop()
        feed = _request_news_window(symbol, window_start, window_end, api_key=api_key, limit=limit, sort=sort)

        if not feed:
            continue

        if len(feed) < limit:
            items.extend(feed)
            continue

        window_minutes = max(int((window_end - window_start).total_seconds() // 60), 0)
        if window_minutes <= min_window_minutes:
            items.extend(feed)
            continue

        midpoint = window_start + (window_end - window_start) / 2
        midpoint = midpoint.replace(second=0, microsecond=0)

        if midpoint <= window_start or midpoint >= window_end:
            items.extend(feed)
            continue

        stack.append((midpoint, window_end))
        stack.append((window_start, midpoint))

        if pause_seconds:
            time.sleep(pause_seconds)

    seen = set()
    unique_items = []
    for item in items:
        key = item.get("url") or f"{item.get('title', '')}|{item.get('time_published', '')}"
        if key in seen:
            continue
        seen.add(key)
        unique_items.append(item)

    return pd.DataFrame(unique_items)


tickers = ["HD", "IBM", "NEM", "WFC", "NFLX","ABBV","C","CSCO","GILD","GLW"]
output_dir = Path("data")
output_dir.mkdir(parents=True, exist_ok=True)

for ticker in tickers:
    df_all_news = fetch_all_news_for_ticker(
        symbol=ticker,
        start="2016-01-01T00:00",
        end="2025-12-31T23:59",
        api_key=AV_KEY,
        sort="RELEVANCE",
    )

    if not df_all_news.empty and "time_published" in df_all_news.columns:
        df_all_news["time_published"] = pd.to_datetime(df_all_news["time_published"], errors="coerce")
        df_all_news = df_all_news.sort_values("time_published").reset_index(drop=True)

    output_path = output_dir / f"{ticker}.parquet"
    df_all_news.to_parquet(output_path, index=False)
    print(f"Saved {len(df_all_news)} rows to {output_path}")
# Out:
# Saved 2391 rows to data\HD.parquet
# Saved 4162 rows to data\IBM.parquet
# Saved 2262 rows to data\NEM.parquet
# Saved 8808 rows to data\WFC.parquet
# Saved 4495 rows to data\NFLX.parquet
# Saved 1976 rows to data\ABBV.parquet
# Saved 8134 rows to data\C.parquet
# Saved 3037 rows to data\CSCO.parquet
# Saved 1809 rows to data\GILD.parquet
# Saved 1241 rows to data\GLW.parquet
