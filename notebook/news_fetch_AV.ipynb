# %%
# NEWS API
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=AAPL&apikey=demo

import requests as r
from dotenv import load_dotenv
import os
import pandas as pd

load_dotenv()
AV_KEY = os.getenv("AV_KEY")

# %%
symbol = "SJM"
# news api
time_from = "20260101T0000"
time_to = "20260604T2359"
sort = "RELEVANCE"
url_base = "https://www.alphavantage.co/query?function=NEWS_SENTIMENT"
limit = 1000
url = f"{url_base}&tickers={symbol}&time_from={time_from}&time_to={time_to}&sort={sort}&limit={limit}&apikey={AV_KEY}"
res = r.get(url)

data = res.json()
df = pd.DataFrame.from_dict(data['feed'])

# %%
df
# Out:
#                                                  title  \
# 0    DAR Financials: Revenue Breakdown, Margins & C...
# 1    A Look At J. M. Smucker’s (SJM) Valuation As M...
# 2    J.M. Smucker stock may move 4.1% on June 9 ear...
# 3    J.M. Smucker stock may move 4.1% on June 9 ear...
# 4    Precision Trading with J.m. Smucker Company (t...
# ..                                                 ...
# 714  Fridge-friendly Uncrustables are coming to Kro...
# 715  J.M. Smucker cuts COO role as part of leadersh...
# 716        J.M. Smucker Co. taps Katie Williams as CMO
# 717  At a Defining Moment for Manufacturing, NAM El...
# 718  Closing with purpose: Smucker’s farewell bring...
#
#                                                    url      time_published  \
# 0       https://intellectia.ai/en/stock/DAR/financials 2026-06-03 08:40:28
# 1    https://simplywall.st/stocks/us/food-beverage-... 2026-06-03 05:59:58
# 2    https://m.investing.com/news/stock-market-news... 2026-06-02 15:38:39
# 3    https://www.investing.com/news/stock-market-ne... 2026-06-02 15:12:31
# 4    https://news.stocktradersdaily.com/news_releas... 2026-06-02 06:56:00
# ..                                                 ...                 ...
# 714  https://www.cincinnati.com/story/grocery/2026/... 2026-02-20 17:00:58
# 715  https://www.crainscleveland.com/manufacturing/... 2026-02-10 18:27:34
# 716  https://www.snackandbakery.com/articles/115173... 2026-02-06 18:28:09
# 717  https://nam.org/at-a-defining-moment-for-manuf... 2026-01-16 00:28:12
# 718  https://www.yourohionews.com/wayne-county/clos... 2026-01-10 11:06:39
#
#               authors                                            summary  \
# 0                  []  The article provides a financial overview of D...
# 1    [Simply Wall St]  J. M. Smucker (SJM) is currently trading at US...
# 2     [Investing.com]  J.M. Smucker Co. shares are predicted to move ...
# 3     [Louis Juricic]  J.M. Smucker Co. shares could see a 4.1% movem...
# 4      [Bianca Flinn]  This article from Stock Traders Daily provides...
# ..                ...                                                ...
# 714    [Kaycee Sloan]  The J.M. Smucker Co. announced that its Uncrus...
# 715   [Scott Suttell]  J.M. Smucker Co. has eliminated the chief oper...
# 716     [SF&WB Staff]  The J.M. Smucker Co., parent company of brands...
# 717                []  The National Association of Manufacturers (NAM...
# 718     [Todd Stumpf]  The J.M. Smucker Co. is closing its store and ...
#
#                                           banner_image  \
# 0                                                  NaN
# 1                                                  NaN
# 2    https://i-invdn-com.investing.com/msite/img/in...
# 3    https://i-invdn-com.investing.com/news/LYNXNPE...
# 4    https://news.stocktradersdaily.com/media/80814...
# ..                                                 ...
# 714  https://www.gannett-cdn.com/authoring/authorin...
# 715  https://s3-prod.crainscleveland.com/styles/wid...
# 716  https://www.snackandbakery.com/ext/resources/2...
# 717  https://nam.org/wp-content/uploads/2019/05/DRB...
# 718  https://image.yourohionews.com/1003809.webp?im...
#
#                                           source category_within_source  \
# 0                                 Intellectia AI                General
# 1                             Simply Wall Street                General
# 2                                  Investing.com                General
# 3                                  Investing.com                General
# 4                            Stock Traders Daily                General
# ..                                           ...                    ...
# 714                          Cincinnati Enquirer                General
# 715                   Crain's Cleveland Business                General
# 716                Snack Food & Wholesale Bakery                General
# 717  National Association of Manufacturers - NAM                General
# 718                               Your Ohio News                General
#
#                                    source_domain  \
# 0                                 Intellectia AI
# 1                             Simply Wall Street
# 2                                  Investing.com
# 3                                  Investing.com
# 4                            Stock Traders Daily
# ..                                           ...
# 714                          Cincinnati Enquirer
# 715                   Crain's Cleveland Business
# 716                Snack Food & Wholesale Bakery
# 717  National Association of Manufacturers - NAM
# 718                               Your Ohio News
#
#                                                 topics  \
# 0    [{'topic': 'earnings', 'relevance_score': '0.9...
# 1    [{'topic': 'financial_markets', 'relevance_sco...
# 2    [{'topic': 'earnings', 'relevance_score': '0.9...
# 3    [{'topic': 'earnings', 'relevance_score': '0.9...
# 4    [{'topic': 'financial_markets', 'relevance_sco...
# ..                                                 ...
# 714  [{'topic': 'retail_wholesale', 'relevance_scor...
# 715  [{'topic': 'retail_wholesale', 'relevance_scor...
# 716  [{'topic': 'retail_wholesale', 'relevance_scor...
# 717  [{'topic': 'manufacturing', 'relevance_score':...
# 718  [{'topic': 'retail_wholesale', 'relevance_scor...
#
#      overall_sentiment_score overall_sentiment_label  \
# 0                   0.151052        Somewhat-Bullish
# 1                   0.041975                 Neutral
# 2                   0.107687                 Neutral
# 3                   0.136611                 Neutral
# 4                   0.434546                 Bullish
# ..                       ...                     ...
# 714                 0.323549        Somewhat-Bullish
# 715                 0.141935                 Neutral
# 716                 0.401943                 Bullish
# 717                 0.448723                 Bullish
# 718                 0.404235                 Bullish
#
#                                       ticker_sentiment
# 0    [{'ticker': 'DAR', 'relevance_score': '1.00000...
# 1    [{'ticker': 'SJM', 'relevance_score': '1.00000...
# 2    [{'ticker': 'SJM', 'relevance_score': '1.00000...
# 3    [{'ticker': 'SJM', 'relevance_score': '1.00000...
# 4    [{'ticker': 'SJM', 'relevance_score': '1.00000...
# ..                                                 ...
# 714  [{'ticker': 'KR', 'relevance_score': '0.909229...
# 715  [{'ticker': 'SJM', 'relevance_score': '1.00000...
# 716  [{'ticker': 'SJM', 'relevance_score': '1.00000...
# 717  [{'ticker': 'SJM', 'relevance_score': '0.94109...
# 718  [{'ticker': 'SJM', 'relevance_score': '1.00000...
#
# [719 rows x 13 columns]

# %%
from datetime import datetime
from pathlib import Path
import time
import pandas as pd
import requests as r

def _format_av_time(dt: datetime) -> str:
    return dt.strftime("%Y%m%dT%H%M")


def _request_news_window(symbol: str, start_dt: datetime, end_dt: datetime, api_key: str, limit: int = 1000, sort: str = "LATEST"):
    url = (
        "https://www.alphavantage.co/query"
        "?function=NEWS_SENTIMENT"
        f"&tickers={symbol}"
        f"&time_from={_format_av_time(start_dt)}"
        f"&time_to={_format_av_time(end_dt)}"
        f"&sort={sort}"
        f"&limit={limit}"
        f"&apikey={api_key}"
    )
    response = r.get(url, timeout=60)
    response.raise_for_status()
    payload = response.json()
    if "Information" in payload or "Note" in payload or "Error Message" in payload:
        raise RuntimeError(payload.get("Information") or payload.get("Note") or payload.get("Error Message"))
    return payload.get("feed", [])


def fetch_all_news_for_ticker(
    symbol: str,
    start: str = "2016-01-01T00:00",
    end: str = "2025-12-31T23:59",
    api_key: str | None = AV_KEY,
    limit: int = 1000,
    sort: str = "RELEVANCE",
    min_window_minutes: int = 60,
    pause_seconds: float = 12.5,
):
    if not api_key:
        raise ValueError("AV_KEY is missing. Set it in your environment before running this cell.")

    start_dt = datetime.fromisoformat(start)
    end_dt = datetime.fromisoformat(end)
    if start_dt >= end_dt:
        raise ValueError("start must be earlier than end")

    stack = [(start_dt, end_dt)]
    items = []

    while stack:
        window_start, window_end = stack.pop()
        feed = _request_news_window(symbol, window_start, window_end, api_key=api_key, limit=limit, sort=sort)

        if not feed:
            continue

        if len(feed) < limit:
            items.extend(feed)
            continue

        window_minutes = max(int((window_end - window_start).total_seconds() // 60), 0)
        if window_minutes <= min_window_minutes:
            items.extend(feed)
            continue

        midpoint = window_start + (window_end - window_start) / 2
        midpoint = midpoint.replace(second=0, microsecond=0)

        if midpoint <= window_start or midpoint >= window_end:
            items.extend(feed)
            continue

        stack.append((midpoint, window_end))
        stack.append((window_start, midpoint))

        if pause_seconds:
            time.sleep(pause_seconds)

    seen = set()
    unique_items = []
    for item in items:
        key = item.get("url") or f"{item.get('title', '')}|{item.get('time_published', '')}"
        if key in seen:
            continue
        seen.add(key)
        unique_items.append(item)

    return pd.DataFrame(unique_items)


tickers = ['AES','SJM']
output_dir = Path("data")
output_dir.mkdir(parents=True, exist_ok=True)

for ticker in tickers:
    df_all_news = fetch_all_news_for_ticker(
        symbol=ticker,
        start="2016-01-01T00:00",
        end="2025-12-31T23:59",
        api_key=AV_KEY,
        sort="RELEVANCE",
    )

    if not df_all_news.empty and "time_published" in df_all_news.columns:
        df_all_news["time_published"] = pd.to_datetime(df_all_news["time_published"], errors="coerce")
        df_all_news = df_all_news.sort_values("time_published").reset_index(drop=True)

    output_path = output_dir / f"{ticker}.parquet"
    df_all_news.to_parquet(output_path, index=False)
    print(f"Saved {len(df_all_news)} rows to {output_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 34
#      30 def fetch_all_news_for_ticker(
#      31     symbol: str,
#      32     start: str = "2016-01-01T00:00",
#      33     end: str = "2025-12-31T23:59",
# ---> 34     api_key: str | None = AV_KEY,
#      35     limit: int = 1000,
#      36     sort: str = "RELEVANCE",
#      37     min_window_minutes: int = 60,
#
# NameError: name 'AV_KEY' is not defined
