# %%
import pandas as pd

# %%
# Load the first dataset
df1 = pd.read_parquet('E:\\Stock-Price-Prediction-using-Advanced-modelling\\data\\3_eda\\filtered_OHLCV.parquet')

df2 = pd.read_parquet('E:\\Stock-Price-Prediction-using-Advanced-modelling\\data\\3_eda\\news_sentiment.parquet')

print('Datasets loaded successfully!')
# Out:
# Datasets loaded successfully!

# %%
df1
# Out:
#         symbol       date        open        high         low       close  \
# 0            A 2016-01-04   37.824543   37.944297   37.161277   37.483696
# 1            A 2016-01-05   37.520545   37.723211   37.161277   37.354729
# 2            A 2016-01-06   37.069159   37.760060   36.894129   37.520546
# 3            A 2016-01-07   36.977030   36.986244   35.751834   35.926861
# 4            A 2016-01-08   36.129522   36.580908   35.438621   35.549164
# ...        ...        ...         ...         ...         ...         ...
# 1220273    ZTS 2025-12-24  122.045745  124.613567  122.006086  124.415276
# 1220274    ZTS 2025-12-26  124.088098  125.238159  123.731180  125.148933
# 1220275    ZTS 2025-12-29  125.079544  125.763629  124.484676  124.901085
# 1220276    ZTS 2025-12-30  124.474765  126.507204  124.375615  125.327400
# 1220277    ZTS 2025-12-31  124.960564  125.753708  124.692872  124.742447
#
#           volume  Daily_Return  Overnight_Gap  HL_Range  ...  Return_Lag2  \
# ...

# %%
df2
# Out:
#        ticker       date  News_Count  Daily_Avg_Sentiment  \
# 0           A 2016-01-05           1             0.122718
# 1           A 2016-02-05           1            -0.638520
# 2           A 2016-02-16           1             0.176532
# 3           A 2016-02-26           1             0.299569
# 4           A 2016-05-11           1             0.426309
# ...       ...        ...         ...                  ...
# 303283    ZTS 2025-12-26           1             0.184648
# 303284    ZTS 2025-12-27           1             0.299451
# 303285    ZTS 2025-12-29           1             0.104321
# 303286    ZTS 2025-12-30           1             0.284957
# 303287    ZTS 2025-12-31           1             0.051227
#
#         Daily_Sentiment_Std  Positive_Ratio  Negative_Ratio  Neutral_Ratio  \
# 0                       0.0        0.122718         0.00000       0.877282
# 1                       0.0        0.000000         0.63852       0.361480
# ...

# %%
merged_df = pd.merge(df1, df2, how='left', left_on=['symbol', 'date'], right_on=['ticker', 'date'])
merged_df
# Out:
#         symbol       date        open        high         low       close  \
# 0            A 2016-01-04   37.824543   37.944297   37.161277   37.483696
# 1            A 2016-01-05   37.520545   37.723211   37.161277   37.354729
# 2            A 2016-01-06   37.069159   37.760060   36.894129   37.520546
# 3            A 2016-01-07   36.977030   36.986244   35.751834   35.926861
# 4            A 2016-01-08   36.129522   36.580908   35.438621   35.549164
# ...        ...        ...         ...         ...         ...         ...
# 1220273    ZTS 2025-12-24  122.045745  124.613567  122.006086  124.415276
# 1220274    ZTS 2025-12-26  124.088098  125.238159  123.731180  125.148933
# 1220275    ZTS 2025-12-29  125.079544  125.763629  124.484676  124.901085
# 1220276    ZTS 2025-12-30  124.474765  126.507204  124.375615  125.327400
# 1220277    ZTS 2025-12-31  124.960564  125.753708  124.692872  124.742447
#
#           volume  Daily_Return  Overnight_Gap  HL_Range  ...  technology  \
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1220278 entries, 0 to 1220277
# Data columns (total 93 columns):
#  #   Column                    Non-Null Count    Dtype
# ---  ------                    --------------    -----
#  0   symbol                    1220278 non-null  str
#  1   date                      1220278 non-null  datetime64[ms]
#  2   open                      1220278 non-null  float64
#  3   high                      1220278 non-null  float64
#  4   low                       1220278 non-null  float64
#  5   close                     1220278 non-null  float64
#  6   volume                    1220278 non-null  int64
#  7   Daily_Return              1219778 non-null  float64
#  8   Overnight_Gap             1219778 non-null  float64
#  9   HL_Range                  1220278 non-null  float64
#  10  CO_Spread                 1220278 non-null  float64
#  11  Upper_Shadow              1220278 non-null  float64
#  12  Lower_Shadow              1220278 non-null  float64
# ...

# %%
merged_df.shape
# Out:
# (1220278, 93)

# %%
merged_df.isnull().sum().max()
# Out:
# np.int64(944229)
